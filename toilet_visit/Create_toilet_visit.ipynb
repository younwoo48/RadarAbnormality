# %%
import pickle as pkl

C_1_toilet = ['10:20:00']
C_2_toilet = ['10:47:00','10:54:00','11:04:00', '11:15:00','11:04:00', '11:25:00','11:36:00']
C_3_toilet = ['12:12:00', '12:20:00', '12:34:00']

D_1_toilet = ['13:26:00','13:45:00']
D_2_toilet = ['14:23:00']
D_3_toilet = ['15:16:00', '16:02:00']

E_1_toilet = ['10:23:00','10:45:00']
E_2_toilet = ['11:07:00']
E_3_toilet = ['12:02:00', '12:29:00']

F_1_toilet = ['14:33:00','14:52:00']
F_2_toilet = ['15:30:00','15:45:00','15:54:00','16:05:00']
F_3_toilet = ['16:35:00', '16:47:00','16:57:00', '17:10:00']

G_1_toilet = ['10:22:00','10:45:00']
G_2_toilet = ['11:21:00','11:31:00','11:52:00','12:06:00']
G_3_toilet = ['12:25:00', '12:34:00','13:00:00']

H_1_toilet = ['10:20:00','10:42:00']
H_2_toilet = ['11:18:00','11:31:00','11:40:00','11:53:00','11:57:00']
H_3_toilet = ['12:25:00', '12:34:00','13:03:00']

I_1_toilet = ['15:01:00','15:21:00']
I_2_toilet = ['16:11:00']
I_3_toilet = ['16:57:00', '17:14:00']


with open('C_1_toilet', 'wb') as file:
    pkl.dump(C_1_toilet, file)
with open('C_2_toilet', 'wb') as file:
    pkl.dump(C_2_toilet, file)
with open('C_3_toilet', 'wb') as file:
    pkl.dump(C_3_toilet, file)
with open('D_1_toilet', 'wb') as file:
    pkl.dump(D_1_toilet, file)
with open('D_2_toilet', 'wb') as file:
    pkl.dump(D_2_toilet, file)
with open('D_3_toilet', 'wb') as file:
    pkl.dump(D_3_toilet, file)
with open('E_1_toilet', 'wb') as file:
    pkl.dump(E_1_toilet, file)
with open('E_2_toilet', 'wb') as file:
    pkl.dump(E_2_toilet, file)
with open('E_3_toilet', 'wb') as file:
    pkl.dump(E_3_toilet, file)
with open('F_1_toilet', 'wb') as file:
    pkl.dump(F_1_toilet, file)
with open('F_2_toilet', 'wb') as file:
    pkl.dump(F_2_toilet, file)
with open('F_3_toilet', 'wb') as file:
    pkl.dump(F_3_toilet, file)
with open('G_1_toilet', 'wb') as file:
    pkl.dump(G_1_toilet, file)
with open('G_2_toilet', 'wb') as file:
    pkl.dump(G_2_toilet, file)
with open('G_3_toilet', 'wb') as file:
    pkl.dump(G_3_toilet, file)
with open('H_1_toilet', 'wb') as file:
    pkl.dump(H_1_toilet, file)
with open('H_2_toilet', 'wb') as file:
    pkl.dump(H_2_toilet, file)
with open('H_3_toilet', 'wb') as file:
    pkl.dump(H_3_toilet, file)
with open('I_1_toilet', 'wb') as file:
    pkl.dump(I_1_toilet, file)
with open('I_2_toilet', 'wb') as file:
    pkl.dump(I_2_toilet, file)
with open('I_3_toilet', 'wb') as file:
    pkl.dump(I_3_toilet, file)
