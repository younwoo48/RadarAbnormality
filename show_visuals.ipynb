# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.gridspec as gridspec
import visualisation
import toCSV

# %%
data_C_1 = visualisation.parse('C',1)
visualisation.clean_data(data_C_1)
visualisation.visualise_heatmap(data_C_1)

# %%
for data in data_C_1:
    print(data['Z'])
# Out:
# 60.31753420829773
# 60.31753420829773
# 60.31753420829773
# 60.31753420829773
# 60.31753420829773
# 60.31753420829773
# 60.31753420829773
# 60.31753420829773
# 60.31753420829773
# 60.31753420829773
# 57.94246792793274
# 55.77461123466492
# 52.04610824584961
# 50.08893013000488
# 47.3934143781662
# 44.04202997684479
# 43.05177330970764
# 38.584691286087036
# 36.79159879684448
# 39.03622329235077
# 39.386552572250366
# 25.89353919029236
# 19.878175854682922
# 14.985010027885437
# 14.278745651245117
# 10.322337597608566
# 31.214547157287598
# 33.08117091655731
# 40.289586782455444
# 44.606027007102966
# 47.15707302093506
# 52.83300280570984
# 42.27798581123352
# 41.0138726234436
# 38.34950029850006
# 41.50819778442383
# 45.01215219497681
# 47.99091815948486
# 55.26564121246338
# 59.371769428253174
# 64.76731300354004
# 70.22358775138855
# 75.97379684448242
# 77.79147624969482
# 84.04045104980469
# 90.46310782432556
# 96.88576459884644
# 100.58846473693848
# 106.77914619445801
# ...

# %%
data_D_1 = visualisation.parse('D',1)
visualisation.clean_data(data_D_1)
visualisation.visualise_heatmap(data_D_1)

# %%
data_E_1 = visualisation.parse('E',1)
visualisation.clean_data(data_E_1)
visualisation.visualise_heatmap(data_E_1)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
data_F_1 = visualisation.parse('F',1)
visualisation.clean_data(data_F_1)
visualisation.visualise_heatmap(data_F_1)

# %%
data_G_1 = visualisation.parse('G',1)
visualisation.clean_data(data_G_1)
visualisation.visualise_heatmap(data_G_1)

# %%
data_H_1 = visualisation.parse('H',1)
visualisation.clean_data(data_H_1)
visualisation.visualise_heatmap(data_H_1)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
